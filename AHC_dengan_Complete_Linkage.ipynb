# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafikafitri11769/Data_Mining/blob/main/AHC_dengan_Complete_Linkage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rafika Fitri H
# # A11.2019.11769

# %%
# import library
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("AHC Data.xlsx")
print(data)
# Out:
#    siswa  DTW  DTT  DMT  DDB
# 0    1.0  2.0  4.0  4.0  3.0
# 1    2.0  3.0  4.0  3.0  5.0
# 2    3.0  4.0  3.0  2.0  5.0
# 3    4.0  1.0  5.0  4.0  2.0
# 4    5.0  3.0  2.0  1.0  3.0

# %%
x = np.asarray(data)
print(x)
# Out:
# [[1. 2. 4. 4. 3.]
#  [2. 3. 4. 3. 5.]
#  [3. 4. 3. 2. 5.]
#  [4. 1. 5. 4. 2.]
#  [5. 3. 2. 1. 3.]]

# %%
#lakukan hierarchical klastering (complete linkage)
Z = linkage(x, 'complete')

# %%
print(Z)
# Out:
# [[1.         2.         2.         2.        ]
#  [0.         3.         3.46410162 2.        ]
#  [4.         5.         4.58257569 3.        ]
#  [6.         7.         5.47722558 5.        ]]

# %%
#plot dendrogram
plt.figure(figsize=(25, 10))
plt.title('Dendrogram Hierarchical Klastering')
plt.xlabel('data')
plt.ylabel('jarak')
dendrogram(Z)
plt.show()
